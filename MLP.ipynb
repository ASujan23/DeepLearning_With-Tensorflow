# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
#Load and preprocess the MLP Model
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
train_images=train_images.reshape((60000,28,28,1)).astype('float32')/255
test_images=test_images.reshape((10000,28,28,1)).astype('float32')/255
train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#Bulid CNN Model
model=models.Sequential()
model.add(layers.Flatten(input_shape=(28,28,1)))
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

# %%
#Compile the model
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
#print the summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109386 (427.29 KB)
# Trainable params: 109386 (427.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Train the model
model.fit(train_images,train_labels,epochs=5,batch_size=64,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 10s 9ms/step - loss: 0.2757 - accuracy: 0.9210 - val_loss: 0.1307 - val_accuracy: 0.9625
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1132 - accuracy: 0.9664 - val_loss: 0.0976 - val_accuracy: 0.9696
# Epoch 3/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0789 - accuracy: 0.9762 - val_loss: 0.0756 - val_accuracy: 0.9768
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0596 - accuracy: 0.9818 - val_loss: 0.0755 - val_accuracy: 0.9768
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0465 - accuracy: 0.9851 - val_loss: 0.0793 - val_accuracy: 0.9760

# %%
test_loss,test_accuracy=model.evaluate(test_images,test_labels)
print(f'Test Accuracy:{test_accuracy}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0793 - accuracy: 0.9760
# Test Accuracy:0.9760000109672546
