# %% [markdown]
# # Word embeddings for IMDB dataset.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten

# %%
max_features = 10000
max_len = 200
embedding_dim = 32

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=max_features)
train_data = pad_sequences(train_data, maxlen=max_len)
test_data = pad_sequences(test_data, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(Embedding(max_features, embedding_dim, input_length=max_len))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 32)           320000
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 1)                 6401
#
# =================================================================
# Total params: 326401 (1.25 MB)
# Trainable params: 326401 (1.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_data, train_labels, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 4s 10ms/step - loss: 0.5575 - accuracy: 0.7157 - val_loss: 0.3478 - val_accuracy: 0.8638
# Epoch 2/5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2551 - accuracy: 0.9029 - val_loss: 0.2902 - val_accuracy: 0.8768
# Epoch 3/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1596 - accuracy: 0.9466 - val_loss: 0.2841 - val_accuracy: 0.8800
# Epoch 4/5
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0961 - accuracy: 0.9768 - val_loss: 0.2915 - val_accuracy: 0.8854
# Epoch 5/5
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0549 - accuracy: 0.9923 - val_loss: 0.3063 - val_accuracy: 0.8822

# %%
test_loss, test_acc = model.evaluate(test_data, test_labels)
print(f'test accuracy: {test_acc}')
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3216 - accuracy: 0.8718
# test accuracy: 0.8718400001525879
